# %%
from pathlib import Path

from cadet_simplified import (
    list_column_models,
    list_binding_models,
    list_operation_modes,
    get_operation_mode,
    ExcelTemplateGenerator,
    parse_excel,
    plotting,
    SimulationRunner,
    FileStorage,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 from pathlib import Path
# ----> 3 from cadet_simplified import (
#       4     list_column_models,
#       5     list_binding_models,
#       6     list_operation_modes,
#       7     get_operation_mode,
#       8     ExcelTemplateGenerator,
#       9     parse_excel,
#      10     plotting,
#      11     SimulationRunner,
#      12     # Storage
#      13     FileStorage,
#      14 )
#
# File ~/github_repos/cadetgui/cadet_simplified/__init__.py:36
#      29 from .simulation import (
#      30     SimulationRunner,
#      31     SimulationResultWrapper,
#      32     ValidationResult,
#      33 )
#      35 # Excel templates
# ---> 36 from .excel import (
#      37     ExcelTemplateGenerator,
#      38     ExcelParser,
#      39     ParseResult,
#      40     parse_excel,
#      41 )
#      43 # Storage
#      44 from .storage import (
#      45     FileStorage,
#      46     LoadedExperiment,
#      47     ExperimentInfo,
#      48 )
#
# File ~/github_repos/cadetgui/cadet_simplified/excel/__init__.py:21
#       1 """Excel template generation and parsing.
#       2
#       3 Example - Generate template:
#    (...)     18     ...         print(exp.name)
#      19 """
# ---> 21 from .template_generator import ExcelTemplateGenerator
#      22 from .parser import ExcelParser, ParseResult, parse_excel
#      24 __all__ = [
#      25     'ExcelTemplateGenerator',
#      26     'ExcelParser',
#      27     'ParseResult',
#      28     'parse_excel',
#      29 ]
#
# File ~/github_repos/cadetgui/cadet_simplified/excel/template_generator.py:23
#      20 from io import BytesIO
#      21 from typing import Any
# ---> 23 import pandas as pd
#      25 from ..configs import (
#      26     get_binding_model_config,
#      27     get_column_model_config,
#      28     list_binding_models,
#      29     list_column_models,
#      30 )
#      31 from ..operation_modes import get_operation_mode, list_operation_modes
#
# File ~/miniconda3/envs/cadet/lib/python3.13/site-packages/pandas/__init__.py:22
#      18 del _hard_dependencies, _dependency
#      20 try:
#      21     # numpy compat
# ---> 22     from pandas.compat import (
#      23         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      24     )
#      25 except ImportError as _err:  # pragma: no cover
#      26     _module = _err.name
#
# File ~/miniconda3/envs/cadet/lib/python3.13/site-packages/pandas/compat/__init__.py:28
#      18 from pandas.compat._constants import (
#      19     CHAINED_WARNING_DISABLED,
#      20     IS64,
#    (...)     25     WASM,
#      26 )
#      27 from pandas.compat.numpy import is_numpy_dev
# ---> 28 from pandas.compat.pyarrow import (
#      29     HAS_PYARROW,
#      30     PYARROW_MIN_VERSION,
#      31     pa_version_under14p0,
#      32     pa_version_under14p1,
#      33     pa_version_under16p0,
#      34     pa_version_under17p0,
#      35     pa_version_under18p0,
#      36     pa_version_under19p0,
#      37     pa_version_under20p0,
#      38     pa_version_under21p0,
#      39 )
#      41 if TYPE_CHECKING:
#      42     from pandas._typing import F
#
# File ~/miniconda3/envs/cadet/lib/python3.13/site-packages/pandas/compat/pyarrow.py:11
#       8 try:
#       9     import pyarrow as pa
# ---> 11     _palv = Version(Version(pa.__version__).base_version)
#      12     pa_version_under14p0 = _palv < Version("14.0.0")
#      13     pa_version_under14p1 = _palv < Version("14.0.1")
#
# AttributeError: module 'pyarrow' has no attribute '__version__'

# %%
print(100 * "=")
print("SUPPORTED COLUMN MODELS")
print(list_column_models())
print(100 * "-")
print("SUPPORTED BINDING MODELS")
print(list_binding_models())
print(100 * "-")
print("SUPPORTED OPERATION MODES")
print(list_operation_modes())
print(100 * "=")

# %%
col = "LumpedRateModelWithoutPores"
bim = "StericMassAction"
opm = "LWE_concentration_based"
n_components = 3

template_generator = ExcelTemplateGenerator(
    operation_mode=opm,
    column_model=col,
    binding_model=bim,
    n_components=n_components,
    component_names=["Salt", "Product", "Impurity1"],
)

save_path = Path("~").expanduser()
excel_template_file = save_path / "test_template.xlsx"
template_generator.save(excel_template_file)
print(f"Template saved to: {excel_template_file}")


filled_template_path = save_path / "test_template_filled.xlsx"


result = parse_excel(filled_template_path)


operation_mode = get_operation_mode(opm)
process_list = []

for exp in result.experiments:
    process = operation_mode.create_process(exp, result.column_binding)
    process_list.append(process)
    

    print(process.check_config())


runner = SimulationRunner()

print("\nRunning simulations...")
results = runner.run_batch(
    process_list,
    stop_on_error=False,
    progress_callback=lambda current, total, res: print(
        f"  [{current}/{total}] {res.experiment_name}: "
        f"{'Success' if res.success else 'Failed'} ({res.runtime_seconds:.2f}s)"
    ),
)


storage_dir = save_path / "cadet_experiments"
storage = FileStorage(storage_dir)

set_id = storage.save_experiment_set(
    name="my_study",
    operation_mode=opm,
    experiments=result.experiments,
    column_binding=result.column_binding,
    results=results,
    description="Test simulation run",
)

# %%
df = storage.list_experiments(limit=10)
df

# %%
# Load specific experiments
loaded = storage.load_results_by_selection(
    selections=[(set_id, exp.name) for exp in result.experiments],
    include_chromatogram=True,
)

print(f"\nLoaded {len(loaded)} experiment(s) for analysis")

# %%
p = plotting.plot_chromatogram(results[0])
